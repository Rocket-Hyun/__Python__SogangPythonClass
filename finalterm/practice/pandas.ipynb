# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
commits_df = pd.read_csv('./data/github_commits.csv')
#row name과 sep를 주고 싶을 때
fixed_df = pd.read_csv('./data/github_commits_sep.csv', sep=':', encoding='utf-8', index_col='date')

# %%
commits_df
# Out:
#           date  yjo2lee  chanha22  pixar0407  deyim  Rocket-Hyun  chloejiwon
# 0   2017-11-07        0         1          0      1            1           0
# 1   2017-11-08        0         1          0      4            0           0
# 2   2017-11-09        4         0          4      1           42           0
# 3   2017-11-10        0         1          1      3            1           0
# 4   2017-11-11        1         0          2      3            5           0
# 5   2017-11-12        1         1          1      1           11           1
# 6   2017-11-13        1         0          3      3            6           3
# 7   2017-11-14        1         0          4      4            1           2
# 8   2017-11-15        1         1          3      4            4           0
# 9   2017-11-16        1         1          1      4            5           5
# 10  2017-11-17        1         1          1      3            6           1
# 11  2017-11-18        0         0          1      1            1           1
# 12  2017-11-19        3         2          2      1            5           0
# 13  2017-11-20        1         0          1      1            6           1
# 14  2017-11-21        1         0          2      2            4           4
# 15  2017-11-22        1         0          3      3            0           1
# 16  2017-11-23        0         3          3      4           25           2
# 17  2017-11-24        1         2          1      1           49           0
# 18  2017-11-25        1         5          0      2            2           0
# 19  2017-11-26        1         2          1      1            1           2
# 20  2017-11-27        0        12          1      2            0           3
# 21  2017-11-28        1         5          0      2            9           5
# 22  2017-11-29        1         1          1      2            0           0
# 23  2017-11-30        3         0          0      2            0           3
# 24  2017-12-01        2         2          4      1            2           0
# 25  2017-12-02        4         2          1      2            1           1
# 26  2017-12-03        1         1          4      3            1           0
# 27  2017-12-04        1         3          1      1            3           1
# 28  2017-12-05        1         2          1      1            1           3
# 29  2017-12-06        1         0          4      1            7           2
# 30  2017-12-07        0         0          4      1            2           3
# 31  2017-12-08        1         0          1      1            1           0
# 32  2017-12-09        1         2          1      1            7           1
# 33  2017-12-10        1         0          1      1            4           0
# 34  2017-12-11        2         0          1      3            7           3
# 35  2017-12-12        1         0          0      1            1           1
# 36  2017-12-13        1         1          1      1            1           0
# 37  2017-12-14        1         0          2      1            0           1
# 38  2017-12-15        1         0          4      1            2           1

# %%
commits_df[:1]
# Out:
#          date  yjo2lee  chanha22  pixar0407  deyim  Rocket-Hyun  chloejiwon
# 0  2017-11-07        0         1          0      1            1           0

# %%
fixed_df[:1]
# Out:
#             yjo2lee  chanha22  pixar0407  deyim  Rocket-Hyun  chloejiwon
# date
# 2017-11-07        0         1          0      1            1           0

# %%
commits_df.index
# Out:
# RangeIndex(start=0, stop=39, step=1)

# %%
fixed_df.index
# list로 받으려면
#list(fixed_df.index)
# Out:
# Index(['2017-11-07', '2017-11-08', '2017-11-09', '2017-11-10', '2017-11-11',
#        '2017-11-12', '2017-11-13', '2017-11-14', '2017-11-15', '2017-11-16',
#        '2017-11-17', '2017-11-18', '2017-11-19', '2017-11-20', '2017-11-21',
#        '2017-11-22', '2017-11-23', '2017-11-24', '2017-11-25', '2017-11-26',
#        '2017-11-27', '2017-11-28', '2017-11-29', '2017-11-30', '2017-12-01',
#        '2017-12-02', '2017-12-03', '2017-12-04', '2017-12-05', '2017-12-06',
#        '2017-12-07', '2017-12-08', '2017-12-09', '2017-12-10', '2017-12-11',
#        '2017-12-12', '2017-12-13', '2017-12-14', '2017-12-15'],
#       dtype='object', name='date')

# %%
# 1개 columns 선택시
fixed_df['yjo2lee'][:5]
# Out:
# date
# 2017-11-07    0
# 2017-11-08    0
# 2017-11-09    4
# 2017-11-10    0
# 2017-11-11    1
# Name: yjo2lee, dtype: int64

# %%
# multiple columns 선택시
fixed_df[['yjo2lee','deyim']][:5]
# Out:
#             yjo2lee  deyim
# date
# 2017-11-07        0      1
# 2017-11-08        0      4
# 2017-11-09        4      1
# 2017-11-10        0      3
# 2017-11-11        1      3

# %%
plt.plot(fixed_df[['yjo2lee','deyim', 'pixar0407']][15:])
plt.ylabel('commits')
plt.xlabel('date')
plt.show()

# %%
y = fixed_df['Rocket-Hyun']
x = fixed_df.index
plt.bar(x, y,color="blue")
plt.ylabel('commits')
plt.xlabel('date')
plt.show()

# %%
# 빈도수 확인
fixed_df['Rocket-Hyun'].value_counts()
# Out:
# 1     11
# 0      6
# 2      4
# 7      3
# 6      3
# 5      3
# 4      3
# 49     1
# 42     1
# 25     1
# 11     1
# 9      1
# 3      1
# Name: Rocket-Hyun, dtype: int64

# %%
# 평균
fixed_df[['Rocket-Hyun', 'deyim']].mean(axis=0)
# Out:
# Rocket-Hyun    5.743590
# deyim          1.923077
# dtype: float64

# %%
# axis = 0 => columns 별
# axis = 1 => rows 별
print(fixed_df.mean(axis=1)[:3])
print(fixed_df.sum(axis=1)[:5])
# Out:
# date
# 2017-11-07    0.500000
# 2017-11-08    0.833333
# 2017-11-09    8.500000
# dtype: float64
# date
# 2017-11-07     3
# 2017-11-08     5
# 2017-11-09    51
# 2017-11-10     6
# 2017-11-11    11
# dtype: int64

# %%
# 행 또는 열이 몇개인지
fixed_df.count()
# Out:
# yjo2lee        39
# chanha22       39
# pixar0407      39
# deyim          39
# Rocket-Hyun    39
# chloejiwon     39
# dtype: int64

# %%
# 서머리
fixed_df.describe()
# Out:
#          yjo2lee   chanha22  pixar0407      deyim  Rocket-Hyun  chloejiwon
# count  39.000000  39.000000  39.000000  39.000000     39.00000   39.000000
# mean    1.128205   1.333333   1.692308   1.923077      5.74359    1.307692
# std     0.950886   2.180455   1.360221   1.109400     10.41183    1.453740
# min     0.000000   0.000000   0.000000   1.000000      0.00000    0.000000
# 25%     1.000000   0.000000   1.000000   1.000000      1.00000    0.000000
# 50%     1.000000   1.000000   1.000000   1.000000      2.00000    1.000000
# 75%     1.000000   2.000000   3.000000   3.000000      6.00000    2.000000
# max     4.000000  12.000000   4.000000   4.000000     49.00000    5.000000
