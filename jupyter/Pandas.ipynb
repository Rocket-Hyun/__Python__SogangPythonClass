# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\qk'

# %%
path = "usagov_bitly_data.2013-05-17.clean.csv"
open(path).readline()
# Out:
# '{ "a": "Mozilla/5.0 (iPad; CPU OS 6_1_3 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10B329 Safari/8536.25", "c": "US", "nk": 0, "tz": "America/Chicago", "gr": "WI", "g": "YmtpnZ", "h": "YmtpnZ", "l": "bitly", "al": "en-us", "hh": "1.usa.gov", "r": "http://www.waukesha.k12.wi.us/", "u": "http://pld.dpi.wi.gov/files/pld/images/LinkWI.png", "t": 1368749945, "hc": 1363711958, "cy": "Brookfield", "ll": [ 43.060799, -88.155800 ] }\n'

# %%
import json
records = [json.loads(line) for line in open(path, encoding='UTF8')]
records[0]
# Out:
# {'a': 'Mozilla/5.0 (iPad; CPU OS 6_1_3 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10B329 Safari/8536.25',
#  'al': 'en-us',
#  'c': 'US',
#  'cy': 'Brookfield',
#  'g': 'YmtpnZ',
#  'gr': 'WI',
#  'h': 'YmtpnZ',
#  'hc': 1363711958,
#  'hh': '1.usa.gov',
#  'l': 'bitly',
#  'll': [43.060799, -88.1558],
#  'nk': 0,
#  'r': 'http://www.waukesha.k12.wi.us/',
#  't': 1368749945,
#  'tz': 'America/Chicago',
#  'u': 'http://pld.dpi.wi.gov/files/pld/images/LinkWI.png'}

# %%
type(records[0])
# Out:
# dict

# %%
records[0]['tz']
# Out:
# 'America/Chicago'

# %%
time_zones = [rec['tz'] for rec in records]
time_zones
# Out:
# ['America/Chicago',
#  '',
#  'America/Vancouver',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'Asia/Kuala_Lumpur',
#  'America/Chicago',
#  'America/Edmonton',
#  'America/New_York',
#  'America/Chicago',
#  'America/Argentina/Buenos_Aires',
#  'Asia/Calcutta',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'Europe/Moscow',
#  '',
#  'America/Chicago',
#  'America/New_York',
#  'Asia/Dubai',
#  'America/Chicago',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Anchorage',
#  'America/New_York',
#  'Europe/Berlin',
#  'America/Chicago',
#  'Australia/West',
#  'Europe/Berlin',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'Asia/Riyadh',
#  '',
#  'America/Chicago',
#  '',
#  'America/Chicago',
#  '',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Denver',
#  'America/New_York',
#  'Europe/Prague',
#  'America/La_Paz',
#  '',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/Denver',
#  'America/Chicago',
#  '',
#  '',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'Europe/London',
#  'America/Chicago',
#  'Europe/Madrid',
#  'America/Los_Angeles',
#  '',
#  'America/New_York',
#  '',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'America/Rainy_River',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Bogota',
#  '',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  '',
#  'America/Denver',
#  '',
#  'America/Chicago',
#  '',
#  'America/Chicago',
#  'America/New_York',
#  'Pacific/Honolulu',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'Asia/Calcutta',
#  'America/New_York',
#  'America/Denver',
#  '',
#  '',
#  'America/Denver',
#  'America/Denver',
#  'America/Chicago',
#  'America/Denver',
#  'America/Chicago',
#  'America/Denver',
#  'America/Denver',
#  'America/Denver',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'Asia/Tokyo',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'Europe/Moscow',
#  '',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/Edmonton',
#  'America/New_York',
#  'America/Indianapolis',
#  'America/New_York',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/Los_Angeles',
#  'Europe/Moscow',
#  'America/Chicago',
#  'America/Montreal',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Denver',
#  'America/Los_Angeles',
#  'Europe/Sofia',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Rainy_River',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Sao_Paulo',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/Rainy_River',
#  'Europe/Amsterdam',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/Los_Angeles',
#  '',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Los_Angeles',
#  'Europe/London',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'Europe/London',
#  'Australia/NSW',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  '',
#  '',
#  'Asia/Riyadh',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'Europe/London',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  '',
#  'America/Chicago',
#  'America/New_York',
#  'Australia/West',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  '',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Halifax',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'Europe/London',
#  'America/New_York',
#  'America/Halifax',
#  'America/New_York',
#  '',
#  '',
#  '',
#  'America/Chicago',
#  '',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Phoenix',
#  'America/Chicago',
#  'America/Denver',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'Europe/Zagreb',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'Asia/Tokyo',
#  'Asia/Tokyo',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Guatemala',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Denver',
#  'Europe/Luxembourg',
#  'America/Sao_Paulo',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'Europe/Madrid',
#  'America/Los_Angeles',
#  'Australia/Queensland',
#  '',
#  'America/Chicago',
#  'America/Chicago',
#  'Asia/Tokyo',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Indianapolis',
#  'America/Regina',
#  'America/Chicago',
#  'Asia/Tokyo',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/Los_Angeles',
#  '',
#  '',
#  'Asia/Tokyo',
#  'America/New_York',
#  'America/Denver',
#  'America/Chicago',
#  'America/Chicago',
#  '',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Los_Angeles',
#  '',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'America/Denver',
#  'America/New_York',
#  'America/New_York',
#  'Asia/Manila',
#  'America/Los_Angeles',
#  'America/New_York',
#  '',
#  'Europe/London',
#  'Asia/Tokyo',
#  'Europe/Berlin',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'Australia/NSW',
#  'America/Chicago',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/Monterrey',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'Asia/Tokyo',
#  'America/New_York',
#  'America/Mexico_City',
#  'America/New_York',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Denver',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'Asia/Hong_Kong',
#  'America/Chicago',
#  'Asia/Manila',
#  'America/New_York',
#  'America/Chicago',
#  'Australia/Canberra',
#  '',
#  'America/New_York',
#  '',
#  'Asia/Tokyo',
#  'Asia/Hong_Kong',
#  '',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'Australia/Victoria',
#  'America/Indianapolis',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Caracas',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Denver',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'America/Denver',
#  'America/Chicago',
#  '',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'Asia/Singapore',
#  'America/New_York',
#  'Europe/London',
#  '',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'America/New_York',
#  'America/Bogota',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Mexico_City',
#  'Africa/Windhoek',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'Asia/Tokyo',
#  'America/New_York',
#  'America/Chicago',
#  'Europe/Moscow',
#  'America/New_York',
#  'America/Los_Angeles',
#  '',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'Asia/Colombo',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Los_Angeles',
#  '',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'Australia/NSW',
#  'America/New_York',
#  'America/New_York',
#  'America/Denver',
#  '',
#  '',
#  '',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/Bogota',
#  'America/Halifax',
#  '',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'Atlantic/Reykjavik',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Bogota',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Halifax',
#  'Asia/Calcutta',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/Indianapolis',
#  'America/Recife',
#  'America/New_York',
#  'Asia/Tokyo',
#  'America/Chicago',
#  'America/Denver',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  '',
#  'America/Los_Angeles',
#  'America/Chicago',
#  '',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Denver',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  '',
#  '',
#  '',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/Chicago',
#  '',
#  '',
#  '',
#  'Asia/Calcutta',
#  'America/Los_Angeles',
#  'America/Rainy_River',
#  '',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'Asia/Tokyo',
#  '',
#  'America/Rainy_River',
#  '',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'America/Puerto_Rico',
#  'America/Chicago',
#  'America/New_York',
#  'America/Denver',
#  'America/Los_Angeles',
#  '',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'Europe/London',
#  'America/New_York',
#  'America/New_York',
#  'America/Denver',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Rainy_River',
#  'America/Phoenix',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Vancouver',
#  '',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/Indianapolis',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Dominica',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'Asia/Calcutta',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Phoenix',
#  '',
#  'America/New_York',
#  'Europe/London',
#  'America/New_York',
#  'Asia/Tokyo',
#  '',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/Vancouver',
#  'America/Chicago',
#  'Asia/Tokyo',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/Mexico_City',
#  'Asia/Tokyo',
#  'America/Chicago',
#  'America/Phoenix',
#  'America/Chicago',
#  'Asia/Tokyo',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Rainy_River',
#  'America/Phoenix',
#  'Europe/London',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Phoenix',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Rainy_River',
#  'America/New_York',
#  'America/Panama',
#  'America/New_York',
#  'Asia/Brunei',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Rainy_River',
#  'Asia/Tokyo',
#  'America/Rainy_River',
#  'Europe/London',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  'America/Phoenix',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Indianapolis',
#  'America/Chicago',
#  'America/Mexico_City',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/Rainy_River',
#  'America/Anchorage',
#  'Asia/Brunei',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/Phoenix',
#  'America/New_York',
#  'Europe/London',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  '',
#  '',
#  'America/Chicago',
#  'America/New_York',
#  'Europe/Prague',
#  'America/Chicago',
#  '',
#  'America/Chicago',
#  'America/New_York',
#  'America/Chicago',
#  'Asia/Brunei',
#  'America/Chicago',
#  'America/Chicago',
#  '',
#  'America/Mexico_City',
#  'America/Caracas',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  'America/Phoenix',
#  'America/Chicago',
#  '',
#  'America/Chicago',
#  '',
#  '',
#  'America/Nassau',
#  'America/Nassau',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/Rainy_River',
#  'America/New_York',
#  'America/New_York',
#  'Australia/NSW',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/Chicago',
#  'Europe/London',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Rainy_River',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/Argentina/Cordoba',
#  'America/New_York',
#  'America/Bogota',
#  'America/Argentina/Buenos_Aires',
#  'Asia/Dubai',
#  'Asia/Jakarta',
#  'America/Los_Angeles',
#  'America/Indianapolis',
#  '',
#  '',
#  'Europe/London',
#  'America/New_York',
#  'America/Rainy_River',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Los_Angeles',
#  '',
#  'America/New_York',
#  'America/Chicago',
#  'America/Los_Angeles',
#  '',
#  'America/New_York',
#  'Europe/Amsterdam',
#  'America/Phoenix',
#  'America/Denver',
#  '',
#  'Europe/Bucharest',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/New_York',
#  'America/Rainy_River',
#  'America/Edmonton',
#  'America/New_York',
#  'America/Sao_Paulo',
#  '',
#  'America/New_York',
#  'America/New_York',
#  'America/Mexico_City',
#  'America/Chicago',
#  '',
#  '',
#  'America/New_York',
#  'America/Phoenix',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Indianapolis',
#  'America/Rainy_River',
#  'Europe/Madrid',
#  'Asia/Jerusalem',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'Europe/Luxembourg',
#  'America/Martinique',
#  'America/New_York',
#  'America/Chicago',
#  'America/Indianapolis',
#  'America/Chicago',
#  'America/Chicago',
#  'Asia/Karachi',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Halifax',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Chicago',
#  '',
#  'America/New_York',
#  'Asia/Kuching',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/Argentina/Buenos_Aires',
#  'America/New_York',
#  '',
#  'America/Sao_Paulo',
#  'America/Los_Angeles',
#  'Chile/Continental',
#  'America/New_York',
#  'America/Los_Angeles',
#  'Europe/Berlin',
#  'America/Chicago',
#  'America/Phoenix',
#  'Asia/Calcutta',
#  'America/Chicago',
#  'America/New_York',
#  'Pacific/Auckland',
#  'America/Chicago',
#  'Asia/Colombo',
#  'America/New_York',
#  'Europe/London',
#  'America/Chicago',
#  'America/New_York',
#  'Asia/Bangkok',
#  'America/Mexico_City',
#  'America/Chicago',
#  'America/Chicago',
#  'Asia/Tokyo',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'America/Chicago',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/Costa_Rica',
#  'America/Chicago',
#  'Asia/Calcutta',
#  'America/Mexico_City',
#  'America/Los_Angeles',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/New_York',
#  'America/Sao_Paulo',
#  'America/Vancouver',
#  'America/Los_Angeles',
#  '',
#  'America/Chicago',
#  'America/Edmonton',
#  'America/New_York',
#  'America/New_York',
#  'America/New_York',
#  'America/Chicago',
#  'America/Rainy_River',
#  'America/Chicago',
#  'America/Chicago',
#  'America/New_York',
#  'America/New_York',
#  '',
#  'America/Chicago',
#  'America/New_York',
#  'Asia/Tokyo',
#  'America/Chicago',
#  'America/Chicago',
#  'Australia/Victoria',
#  '',
#  'America/Chicago',
#  ...]

# %%
from collections import defaultdict
def get_counts(sequence):
    counts = defaultdict(int)
    for x in sequence:
        counts[x] += 1
    return counts

# %%
counts = get_counts(time_zones)
counts['America/New_York']
# Out:
# 32832

# %%
counts
# Out:
# defaultdict(int,
#             {'America/Chicago': 46235,
#              '': 20850,
#              'America/Vancouver': 452,
#              'America/New_York': 32832,
#              'America/Los_Angeles': 13898,
#              'Asia/Kuala_Lumpur': 184,
#              'America/Edmonton': 363,
#              'America/Argentina/Buenos_Aires': 258,
#              'Asia/Calcutta': 1061,
#              'Europe/Moscow': 716,
#              'Asia/Dubai': 121,
#              'America/Anchorage': 242,
#              'Europe/Berlin': 1340,
#              'Australia/West': 140,
#              'Asia/Riyadh': 158,
#              'America/Denver': 3235,
#              'Europe/Prague': 161,
#              'America/La_Paz': 76,
#              'Europe/London': 4551,
#              'Europe/Madrid': 892,
#              'America/Rainy_River': 1565,
#              'America/Bogota': 281,
#              'Pacific/Honolulu': 165,
#              'Asia/Tokyo': 1514,
#              'America/Indianapolis': 1330,
#              'America/Montreal': 459,
#              'Europe/Sofia': 88,
#              'America/Sao_Paulo': 557,
#              'Europe/Amsterdam': 751,
#              'Australia/NSW': 454,
#              'America/Halifax': 185,
#              'America/Phoenix': 1440,
#              'Europe/Zagreb': 96,
#              'America/Guatemala': 31,
#              'Europe/Luxembourg': 24,
#              'Australia/Queensland': 238,
#              'America/Regina': 55,
#              'Asia/Manila': 339,
#              'America/Monterrey': 120,
#              'America/Mexico_City': 453,
#              'Asia/Hong_Kong': 374,
#              'Australia/Canberra': 34,
#              'Australia/Victoria': 431,
#              'America/Caracas': 186,
#              'Asia/Singapore': 134,
#              'Africa/Windhoek': 11,
#              'Asia/Colombo': 34,
#              'Atlantic/Reykjavik': 25,
#              'America/Recife': 34,
#              'America/Puerto_Rico': 317,
#              'America/Dominica': 2,
#              'America/Panama': 32,
#              'Asia/Brunei': 5,
#              'America/Nassau': 17,
#              'America/Argentina/Cordoba': 20,
#              'Asia/Jakarta': 166,
#              'Europe/Bucharest': 155,
#              'Asia/Jerusalem': 127,
#              'America/Martinique': 2,
#              'Asia/Karachi': 144,
#              'Asia/Kuching': 12,
#              'Chile/Continental': 210,
#              'Pacific/Auckland': 227,
#              'Asia/Bangkok': 124,
#              'America/Costa_Rica': 102,
#              'Asia/Istanbul': 285,
#              'Europe/Warsaw': 293,
#              'Asia/Harbin': 92,
#              'America/Whitehorse': 5,
#              'America/Lima': 92,
#              'America/Barbados': 3,
#              'Europe/Vienna': 208,
#              'Europe/Brussels': 303,
#              'Australia/Tasmania': 22,
#              'Africa/Johannesburg': 323,
#              'Europe/Ljubljana': 47,
#              'Asia/Irkutsk': 3,
#              'America/Winnipeg': 82,
#              'Asia/Seoul': 83,
#              'Europe/Rome': 698,
#              'America/Port_of_Spain': 24,
#              'America/Tijuana': 51,
#              'Asia/Taipei': 138,
#              'America/Santo_Domingo': 57,
#              'America/Cancun': 10,
#              'America/El_Salvador': 28,
#              'America/Merida': 24,
#              'Europe/Dublin': 266,
#              'America/Guayaquil': 89,
#              'America/Guyana': 3,
#              'Europe/Paris': 717,
#              'Asia/Shanghai': 74,
#              'Australia/South': 85,
#              'America/St_Johns': 23,
#              'America/Chihuahua': 52,
#              'Asia/Chongqing': 30,
#              'America/Belem': 9,
#              'America/Bahia': 25,
#              'Africa/Cairo': 87,
#              'Africa/Lagos': 38,
#              'Europe/Athens': 198,
#              'America/Mazatlan': 88,
#              'Europe/Lisbon': 180,
#              'Asia/Phnom_Penh': 45,
#              'Asia/Yekaterinburg': 26,
#              'Europe/Budapest': 111,
#              'Europe/Helsinki': 144,
#              'Africa/Ceuta': 152,
#              'Asia/Novokuznetsk': 8,
#              'America/Tegucigalpa': 51,
#              'America/Asuncion': 23,
#              'Europe/Oslo': 152,
#              'America/Managua': 9,
#              'America/Hermosillo': 17,
#              'Asia/Dhaka': 25,
#              'Europe/Stockholm': 458,
#              'America/Fortaleza': 13,
#              'America/Argentina/Mendoza': 18,
#              'America/Manaus': 8,
#              'America/Montevideo': 34,
#              'Pacific/Fiji': 1,
#              'Africa/Nairobi': 64,
#              'Europe/Sarajevo': 25,
#              'Asia/Krasnoyarsk': 3,
#              'America/Argentina/San_Luis': 8,
#              'Europe/Samara': 33,
#              'Europe/Belgrade': 81,
#              'Asia/Novosibirsk': 11,
#              'America/Cuiaba': 9,
#              'Africa/Dar_es_Salaam': 11,
#              'Indian/Maldives': 14,
#              'Europe/Isle_of_Man': 10,
#              'Asia/Beirut': 22,
#              'Europe/Copenhagen': 187,
#              'Pacific/Port_Moresby': 1,
#              'Australia/North': 4,
#              'Asia/Bahrain': 3,
#              'Asia/Katmandu': 28,
#              'Pacific/Saipan': 3,
#              'Europe/Zurich': 160,
#              'America/Campo_Grande': 2,
#              'America/Argentina/Rio_Gallegos': 4,
#              'Pacific/Guam': 9,
#              'Asia/Choibalsan': 3,
#              'America/Aruba': 7,
#              'Europe/Volgograd': 24,
#              'Indian/Mauritius': 10,
#              'Europe/Riga': 30,
#              'Europe/Zaporozhye': 14,
#              'Africa/Lusaka': 12,
#              'Asia/Qatar': 28,
#              'Asia/Kuwait': 23,
#              'America/Argentina/San_Juan': 3,
#              'America/Yellowknife': 5,
#              'America/Curacao': 2,
#              'Africa/Algiers': 27,
#              'Asia/Almaty': 5,
#              'Europe/Tallinn': 27,
#              'Asia/Macao': 8,
#              'Asia/Bishkek': 1,
#              'Europe/Bratislava': 53,
#              'America/Porto_Velho': 2,
#              'Asia/Rangoon': 1,
#              'Asia/Tbilisi': 11,
#              'America/Jamaica': 16,
#              'Asia/Amman': 18,
#              'Asia/Tehran': 3,
#              'Europe/Vilnius': 41,
#              'Europe/Skopje': 16,
#              'Asia/Aden': 2,
#              'Africa/Kampala': 32,
#              'Africa/Gaborone': 27,
#              'Africa/Casablanca': 24,
#              'Africa/Harare': 11,
#              'Africa/Mbabane': 4,
#              'Europe/Jersey': 11,
#              'Asia/Muscat': 14,
#              'Atlantic/Canary': 54,
#              'Africa/Maputo': 3,
#              'Asia/Nicosia': 24,
#              'Europe/Tirane': 8,
#              'Pacific/Marquesas': 1,
#              'Europe/Minsk': 9,
#              'Europe/Podgorica': 7,
#              'Asia/Baghdad': 11,
#              'Indian/Antananarivo': 2,
#              'Europe/Chisinau': 3,
#              'Asia/Pontianak': 2,
#              'Africa/Luanda': 2,
#              'Europe/Malta': 22,
#              'Europe/Simferopol': 5,
#              'Europe/Uzhgorod': 10,
#              'Europe/Andorra': 3,
#              'Pacific/Chatham': 5,
#              'Africa/Tripoli': 21,
#              'Africa/Accra': 12,
#              'Asia/Vientiane': 1,
#              'Asia/Kabul': 3,
#              'Asia/Vladivostok': 5,
#              'America/Cayenne': 2,
#              'Asia/Omsk': 4,
#              'Europe/Mariehamn': 1,
#              'Africa/Abidjan': 2,
#              'America/Guadeloupe': 5,
#              'America/Argentina/Salta': 2,
#              'Europe/Kiev': 6,
#              'America/Paramaribo': 4,
#              'America/Havana': 8,
#              'America/Argentina/Tucuman': 4,
#              'Africa/Maseru': 1,
#              'America/St_Kitts': 1,
#              'America/Araguaina': 1,
#              'Asia/Makassar': 2,
#              'Atlantic/Bermuda': 12,
#              'America/Cayman': 2,
#              'Europe/Vaduz': 1,
#              'America/St_Thomas': 2,
#              'Asia/Yerevan': 5,
#              'America/Port-au-Prince': 2,
#              'Africa/Tunis': 6,
#              'America/Tortola': 3,
#              'Africa/Dakar': 1,
#              'Indian/Reunion': 1,
#              'America/Maceio': 1,
#              'Europe/Guernsey': 6,
#              'Europe/Gibraltar': 3,
#              'Asia/Thimphu': 1,
#              'Asia/Aqtobe': 1,
#              'Asia/Baku': 4,
#              'Europe/Kaliningrad': 1,
#              'America/Belize': 1,
#              'America/Anguilla': 2,
#              'America/Argentina/Jujuy': 1,
#              'Asia/Gaza': 1,
#              'Atlantic/Madeira': 1,
#              'America/St_Lucia': 2,
#              'Africa/Blantyre': 1,
#              'Pacific/Noumea': 1,
#              'America/Argentina/Catamarca': 1,
#              0: 0,
#              1: 0})

# %%
def top_counts(count_dict, n=10):
    value_key_pairs = [(count, tz) for tz, count in count_dict.items()]
    value_key_pairs.sort()
    return value_key_pairs[-n:]

# %%
top_counts(counts, 30)
# Out:
# [(303, 'Europe/Brussels'),
#  (317, 'America/Puerto_Rico'),
#  (323, 'Africa/Johannesburg'),
#  (339, 'Asia/Manila'),
#  (363, 'America/Edmonton'),
#  (374, 'Asia/Hong_Kong'),
#  (431, 'Australia/Victoria'),
#  (452, 'America/Vancouver'),
#  (453, 'America/Mexico_City'),
#  (454, 'Australia/NSW'),
#  (458, 'Europe/Stockholm'),
#  (459, 'America/Montreal'),
#  (557, 'America/Sao_Paulo'),
#  (698, 'Europe/Rome'),
#  (716, 'Europe/Moscow'),
#  (717, 'Europe/Paris'),
#  (751, 'Europe/Amsterdam'),
#  (892, 'Europe/Madrid'),
#  (1061, 'Asia/Calcutta'),
#  (1330, 'America/Indianapolis'),
#  (1340, 'Europe/Berlin'),
#  (1440, 'America/Phoenix'),
#  (1514, 'Asia/Tokyo'),
#  (1565, 'America/Rainy_River'),
#  (3235, 'America/Denver'),
#  (4551, 'Europe/London'),
#  (13898, 'America/Los_Angeles'),
#  (20850, ''),
#  (32832, 'America/New_York'),
#  (46235, 'America/Chicago')]

# %%
from collections import Counter
counts = Counter(time_zones)
counts.most_common(10)
# Out:
# [('America/Chicago', 46235),
#  ('America/New_York', 32832),
#  ('', 20850),
#  ('America/Los_Angeles', 13898),
#  ('Europe/London', 4551),
#  ('America/Denver', 3235),
#  ('America/Rainy_River', 1565),
#  ('Asia/Tokyo', 1514),
#  ('America/Phoenix', 1440),
#  ('Europe/Berlin', 1340)]

# %%
from pandas import DataFrame, Series

# %%
import pandas as pd

# %%
frame = DataFrame(records)
frame
# Out:
#                                                         a  \
# 0       Mozilla/5.0 (iPad; CPU OS 6_1_3 like Mac OS X)...
# 1       Mozilla/5.0 (Linux; U; Android 4.1.2; en-us; S...
# 2       Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_3 like ...
# 3       Mozilla/5.0 (Windows NT 6.1; rv:20.0) Gecko/20...
# 4       Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 5       Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 6       Dalvik/1.6.0 (Linux; U; Android 4.1.2; HTCONE ...
# 7       Dalvik/1.6.0 (Linux; U; Android 4.1.2; HTCONE ...
# 8       Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9       Dalvik/1.6.0 (Linux; U; Android 4.1.2; HTCONE ...
# 10      Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_3)...
# 11      Dalvik/1.6.0 (Linux; U; Android 4.1.2; HTCONE ...
# 12      Mozilla/5.0 (Windows NT 6.1; rv:20.0) Gecko/20...
# 13      Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
# 14      Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_3 like ...
# 15      Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 16      Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_4 like ...
# 17      Mozilla/5.0 (iPhone; CPU iPhone OS 6_0_1 like ...
# 18      Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_1 like ...
# 19      Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_4 like ...
# 20      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 21      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 22      Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# 23      Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 24      Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8) A...
# 25      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...
# 26      Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
# 27      Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# 28      Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
# 29      Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# ...                                                   ...
# 148461  Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_2 like ...
# 148462  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 148463  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.8; r...
# 148464  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_3)...
# 148465  Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.3...
# 148466  Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_3 like ...
# 148467  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:20.0) G...
# 148468  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 148469  Mozilla/5.0 (compatible; Genieo/1.0 http://www...
# 148470  Mozilla/5.0 (Linux; U; Android 4.0.3; en-gb; H...
# 148471  Mozilla/5.0 (Linux; U; Android 4.1.2; es-es; G...
# 148472                                 ShortLinkTranslate
# 148473  Mozilla/5.0 (Linux; U; Android 2.3.6; en-us; L...
# 148474  Mozilla/5.0 (iPad; CPU OS 6_1_3 like Mac OS X)...
# 148475  Mozilla/5.0 (iPad; CPU OS 6_1_3 like Mac OS X)...
# 148476  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 148477  Mozilla/5.0 (Linux; U; Android 2.3.4; en-us; D...
# 148478  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:20.0) G...
# 148479  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 148480  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_3)...
# 148481  Mozilla/5.0 (Linux; Android 4.0.4; SO-03D Buil...
# 148482  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:17.0) G...
# 148483  Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_4 like ...
# 148484  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 148485  Mozilla/5.0 (iPad; CPU OS 6_1_3 like Mac OS X)...
# 148486  Mozilla/5.0 (Linux; U; Android 2.3.6; en-us; M...
# 148487  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_3)...
# 148488                                 ShortLinkTranslate
# 148489  Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_4 like ...
# 148490  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
#
#                                          al     c                      cy  \
# 0                                     en-us    US              Brookfield
# 1                                     en-US  None                     NaN
# 2                                     en-us    CA                 Langley
# 3                            en-US,en;q=0.5    US              Washington
# 4                                       NaN    US               Blackwood
# 5                            en-US,en;q=0.8    US         North Highlands
# 6                                       NaN    US            New Hartford
# 7                                       NaN    US            New Hartford
# 8                                     en-us    US              Janesville
# 9                                       NaN    US            New Hartford
# 10                           en-US,en;q=0.8    US  Palos Verdes Peninsula
# 11                                      NaN    US            New Hartford
# 12                           en-US,en;q=0.5    US              Washington
# 13                           en-US,en;q=0.8    US               Mukwonago
# 14                                    en-us    US                  Walton
# 15                           en-US,en;q=0.8    MY           Petaling Jaya
# 16                                    en-us    US            Broken Arrow
# 17                                    en-us    CA                 Calgary
# 18                                    en-us    US              Alpharetta
# 19                                    en-us    US          Corpus Christi
# 20                           es-ES,es;q=0.8    AR                 Campana
# 21                           en-US,en;q=0.8    IN                  Jaipur
# 22                                    en-US    US                  Taylor
# 23                           es-ES,es;q=0.8  None                     NaN
# 24                                    en-us    US                Plymouth
# 25                                    en-us    RU                  Moscow
# 26                          es-419,es;q=0.8  None                     NaN
# 27                                    en-US    US                  Austin
# 28                           en-US,en;q=0.8    US              Alexandria
# 29                                    ar-EG    AE               Abu Dhabi
# ...                                     ...   ...                     ...
# 148461                                en-us  None                     NaN
# 148462              ja,en-US;q=0.8,en;q=0.6  None                     NaN
# 148463  fr,fr-fr;q=0.8,en-us;q=0.5,en;q=0.3    CH                Chambesy
# 148464                                en-us    US               Rockville
# 148465                       en-US,en;q=0.8  None                     NaN
# 148466                                en-us    US               Ann Arbor
# 148467                       en-US,en;q=0.5    US             Thomasville
# 148468                       en-US,en;q=0.8    US     Coronado Ntl Forest
# 148469                                  NaN    US         Manhattan Beach
# 148470                         en-GB, en-US  None                     NaN
# 148471                         es-ES, en-US  None                     NaN
# 148472                                  NaN    JP                 Kashiwa
# 148473                                en-US  None                     NaN
# 148474                                en-us    US              Marshfield
# 148475                       en-US,en;q=0.8    US                  Vaughn
# 148476                                en-US    US                 Orlando
# 148477                                en-US    US                Lakewood
# 148478                       en-US,en;q=0.5    US                   Boone
# 148479                       en-US,en;q=0.8  None                     NaN
# 148480                       en-US,en;q=0.8    US                   Logan
# 148481              ja,en-US;q=0.8,en;q=0.6    JP                   Tokyo
# 148482                       en-gb,en;q=0.5    US           Castro Valley
# 148483                                en-us    US            Fayetteville
# 148484                                en-us    US                   Salem
# 148485                                en-us    US                 Grayson
# 148486                                en-US    US                  Mobile
# 148487                                en-us    US              Brookfield
# 148488                                  NaN    JP                 Tsukuba
# 148489                                en-us  None                     NaN
# 148490                                en-us    PR                Guaynabo
#
#               g   gr        h          hc           hh   kw                l  \
# 0        YmtpnZ   WI   YmtpnZ  1363711958    1.usa.gov  NaN            bitly
# 1       183DUQg  NaN  183DUQf  1368710405    1.usa.gov  NaN      fsanewmedia
# 2       16hIfSr   BC  16hIfSq  1368661734    1.usa.gov  NaN     o_4og9tq48m3
# 3        cfyNl3   DC   cfyNl3  1283862716       bit.ly  NaN            bitly
# 4       13n1N4h   NJ  13n1N4g  1368214131    1.usa.gov  NaN           samhsa
# 5       11BVgoo   CA  11BVgon  1368553152    1.usa.gov  NaN    disabilitygov
# 6       170Ym6q   CT  168TiNP  1368513636    1.usa.gov  NaN      twitterfeed
# 7       13gGRbH   CT  13gGRbG  1368513636    1.usa.gov  NaN      twitterfeed
# 8        YmtpnZ   WI   YmtpnZ  1363711958    1.usa.gov  NaN            bitly
# 9       168TjBo   CT  168TjBn  1368513635    1.usa.gov  NaN      twitterfeed
# 10      10GLbA4   CA  10GLbjR  1368638851    1.usa.gov  NaN  foodtechconnect
# 11      16wTd5I   CT  168TiNA  1368513635    1.usa.gov  NaN      twitterfeed
# 12       jRLklv   DC   jRLklv  1308546970    1.usa.gov  NaN            bitly
# 13       YmtpnZ   WI   YmtpnZ  1363711958    1.usa.gov  NaN            bitly
# 14      12eGvCU   KY  12eGvCU  1368741810    1.usa.gov  NaN            bitly
# 15        15r91   12  10OBm3W  1365701422         j.mp  NaN        pontifier
# 16       gxfxCy   OK  17znDol  1368713183    1.usa.gov  NaN       usairforce
# 17      13hA6Gs   AB  13hA6Gr  1368536068  go.nasa.gov  NaN      nasatwitter
# 18      13z2EyP   GA  147mnFe  1368715581       bit.ly  NaN      twitterfeed
# 19      18OdFhW   TX  18OdFhV  1368738515  go.nasa.gov  NaN      nasatwitter
# 20      18OdFhW   01  18OdFhV  1368738515  go.nasa.gov  NaN      nasatwitter
# 21      12EKKZ9   24  10vg1yR  1368742131    1.usa.gov  NaN          stuvw27
# 22      10Iduy8   MI  10Iduy8  1368717131    1.usa.gov  NaN            bitly
# 23        15r91  NaN  10OBm3W  1365701422         j.mp  NaN        pontifier
# 24       YmtpnZ   WI   YmtpnZ  1363711958    1.usa.gov  NaN            bitly
# 25       9m5vPp   48   ZtWLjk  1363749963   mmflint.me  NaN          mmflint
# 26      103dPLP  NaN  13p03Ef  1368718821  go.nasa.gov  NaN      nasatwitter
# 27       ZO58F1   TX  15JSmzl  1368550925  go.nasa.gov  NaN      nasatwitter
# 28       xqXWfg   VA   xqXWfg  1329860963    1.usa.gov  NaN            bitly
# 29      128Dd44   01  128DcNR  1368542829    1.usa.gov  NaN     seekingalpha
# ...         ...  ...      ...         ...          ...  ...              ...
# 148461  15RP5hF  NaN  16Ewvc4  1368818301    1.usa.gov  NaN          rebroth
# 148462  10Kc32m  NaN  10Kc32l  1368809020  go.nasa.gov  NaN      nasatwitter
# 148463  14bmsHn   07  14bmsHn  1368223558    1.usa.gov  NaN            bitly
# 148464  14bmsHn   MD  14bmsHn  1368223558    1.usa.gov  NaN            bitly
# 148465    15r91  NaN  10OBm3W  1365701422         j.mp  NaN        pontifier
# 148466  1084Psg   MI  1084Psg  1368755511         j.mp  NaN            bitly
# 148467    15r91   NC  10OBm3W  1365701422         j.mp  NaN        pontifier
# 148468  186NWQK   AZ  186NWQK  1368828881    1.usa.gov  NaN            bitly
# 148469   YYv1XQ   CA   YYv1XQ  1368710703    1.usa.gov  NaN            bitly
# 148470  12AyUk2  NaN  12AyUk1  1368808362  go.nasa.gov  NaN      nasatwitter
# 148471  12AyUk2  NaN  12AyUk1  1368808362  go.nasa.gov  NaN      nasatwitter
# 148472   YPnFn4   04   YPnFn3  1368833354    1.usa.gov  NaN           hayano
# 148473    15r91  NaN  10OBm3W  1365701422         j.mp  NaN        pontifier
# 148474   YmtpnZ   WI   YmtpnZ  1363711958    1.usa.gov  NaN            bitly
# 148475  16uqtLe   WA  16uqtLd  1368455001    1.usa.gov  NaN     o_33avl0ri1b
# 148476  10WMBv9   FL  10WMBv9  1368826755    1.usa.gov  NaN            bitly
# 148477  14bmsHn   OH  14bmsHn  1368223558    1.usa.gov  NaN            bitly
# 148478  10X5IW8   NC  10X5IW7  1368834590    1.usa.gov  NaN             inws
# 148479   YmtpnZ  NaN   YmtpnZ  1363711958    1.usa.gov  NaN            bitly
# 148480  107xZnW   UT  107xZnW  1368815450    1.usa.gov  NaN            bitly
# 148481  15TFyGK   40  15TFyGJ  1368810402  go.nasa.gov  NaN      nasatwitter
# 148482  11C6yJk   CA  19oVtZN  1368558078    1.usa.gov  NaN        raylahood
# 148483  10ydrrV   GA  10ydrrU  1368806410    1.usa.gov  NaN      fsanewmedia
# 148484  107xZnW   VA  107xZnW  1368815450    1.usa.gov  NaN            bitly
# 148485  107xZnW   KY  107xZnW  1368815450    1.usa.gov  NaN            bitly
# 148486  10WWSaR   AL  10WWSaQ  1368830835    1.usa.gov  NaN             inws
# 148487   YmtpnZ   WI   YmtpnZ  1363711958    1.usa.gov  NaN            bitly
# 148488   YPnFn4   14   YPnFn3  1368833354    1.usa.gov  NaN           hayano
# 148489  17B6VoC  NaN  16n91ZK  1368746683  go.nasa.gov  NaN      nasatwitter
# 148490  10WMBv9   00  10WMBv9  1368826755    1.usa.gov  NaN            bitly
#
#                               ll  nk  \
# 0          [43.060799, -88.1558]   0
# 1                            NaN   0
# 2       [49.099998, -122.650002]   0
# 3        [38.893299, -77.014603]   1
# 4        [39.779598, -75.050499]   0
# 5       [38.668098, -121.373596]   1
# 6          [41.8466, -73.006401]   0
# 7          [41.8466, -73.006401]   0
# 8        [42.694599, -89.142097]   1
# 9          [41.8466, -73.006401]   0
# 10      [33.773201, -118.339798]   0
# 11         [41.8466, -73.006401]   0
# 12       [38.893299, -77.014603]   1
# 13          [42.888599, -88.333]   0
# 14       [38.888199, -84.641701]   0
# 15          [3.0833, 101.650002]   0
# 16       [36.052601, -95.790802]   0
# 17      [51.083302, -114.083298]   0
# 18       [34.091801, -84.220901]   1
# 19       [27.634899, -97.312897]   1
# 20      [-34.168701, -58.959099]   0
# 21          [26.9167, 75.816704]   1
# 22       [42.225601, -83.268501]   1
# 23                           NaN   0
# 24       [43.768501, -88.016098]   0
# 25        [55.752201, 37.615601]   0
# 26                           NaN   0
# 27         [30.2672, -97.743103]   1
# 28       [38.804798, -77.046898]   0
# 29          [24.4667, 54.366699]   1
# ...                          ...  ..
# 148461                       NaN   0
# 148462                       NaN   1
# 148463       [46.242401, 6.1435]   0
# 148464   [39.089199, -77.183502]   1
# 148465                       NaN   0
# 148466   [42.216702, -83.740601]   1
# 148467   [35.882599, -80.082001]   0
# 148468    [31.9582, -110.693001]   0
# 148469  [33.889301, -118.401001]   0
# 148470                       NaN   1
# 148471                       NaN   1
# 148472   [35.854401, 139.968903]   0
# 148473                       NaN   0
# 148474     [44.6688, -90.171799]   0
# 148475  [47.314499, -122.778503]   0
# 148476       [28.3899, -81.4366]   0
# 148477   [41.481701, -81.802399]   0
# 148478   [36.219101, -81.656303]   0
# 148479                       NaN   1
# 148480  [41.641201, -111.896599]   0
# 148481   [35.685001, 139.751404]   1
# 148482     [37.709, -122.088501]   0
# 148483   [33.481098, -84.479797]   0
# 148484     [37.2906, -80.101402]   0
# 148485   [38.336399, -82.992401]   0
# 148486     [30.657499, -88.1586]   1
# 148487     [43.060799, -88.1558]   0
# 148488   [36.083302, 140.116699]   0
# 148489                       NaN   0
# 148490     [18.3876, -66.110802]   1
#
#                                                         r           t  \
# 0                          http://www.waukesha.k12.wi.us/  1368749945
# 1       http://m.facebook.com/l.php?u=http%3A%2F%2F1.u...  1368749947
# 2                                  https://m.facebook.com  1368749947
# 3                                                  direct  1368749948
# 4                                                  direct  1368749948
# 5                                  http://t.co/VZ6ZOL0bFb  1368749949
# 6                                                  direct  1368749948
# 7                                                  direct  1368749949
# 8       http://www.jefferson.k12.wi.us/DocViewBody.pag...  1368749950
# 9                                                  direct  1368749950
# 10                                 http://t.co/bsP3KLgvWp  1368749949
# 11                                                 direct  1368749951
# 12                                                 direct  1368749952
# 13                             http://waukesha.k12.wi.us/  1368749953
# 14                                 https://m.facebook.com  1368749952
# 15                                                 direct  1368749952
# 16                                 https://m.facebook.com  1368749954
# 17                                 http://t.co/R7oHd5SjWa  1368749953
# 18                                 http://t.co/rB9uCSRjxI  1368749955
# 19                                 http://t.co/d6Ox5xoSqv  1368749955
# 20                                 http://t.co/d6Ox5xoSqv  1368749955
# 21                               http://www.facebook.com/  1368749957
# 22                                 http://t.co/JNQI1C9HRW  1368749958
# 23                                                 direct  1368749960
# 24                         http://www.plymouth.k12.wi.us/  1368749960
# 25      http://yandex.ru/yandsearch?text=mmflint.me&lr...  1368749962
# 26                               http://www.facebook.com/  1368749963
# 27      http://www.nasa.gov/home/hqnews/2013/may/HQ_13...  1368749964
# 28                                 http://t.co/9PRAkfv29z  1368749965
# 29      http://seekingalpha.com/article/1409951-affyma...  1368749967
# ...                                                   ...         ...
# 148461                                             direct  1368835776
# 148462                             http://t.co/HgiLLFRDtE  1368835778
# 148463                                             direct  1368835778
# 148464                                             direct  1368835778
# 148465                                             direct  1368835780
# 148466                             http://t.co/orOTdRX5aF  1368835780
# 148467                                             direct  1368835782
# 148468                          https://www.facebook.com/  1368835783
# 148469                                             direct  1368835785
# 148470                                             direct  1368835786
# 148471                             http://t.co/q6402O6lFC  1368835786
# 148472                                             direct  1368835787
# 148473                                             direct  1368835789
# 148474                        http://www.colby.k12.wi.us/  1368835791
# 148475                                 http://fwp.mt.gov/  1368835793
# 148476  http://www.elnuevodia.com/brillanteexplosionen...  1368835794
# 148477                                             direct  1368835794
# 148478  http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1368835793
# 148479                       http://www.cudahy.k12.wi.us/  1368835795
# 148480                          https://www.facebook.com/  1368835795
# 148481                                             direct  1368835795
# 148482                 http://www.cahighspeedrail.ca.gov/  1368835797
# 148483                             http://t.co/psBn8njvIB  1368835797
# 148484  http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1368835798
# 148485  http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1368835801
# 148486  http://m.facebook.com/l.php?u=http%3A%2F%2F1.u...  1368835802
# 148487                       http://www.cudahy.k12.wi.us/  1368835803
# 148488                                             direct  1368835804
# 148489                             http://t.co/XLS75r3BCB  1368835805
# 148490  http://www.elnuevodia.com/brillanteexplosionen...  1368835806
#
#                                     tz  \
# 0                      America/Chicago
# 1
# 2                    America/Vancouver
# 3                     America/New_York
# 4                     America/New_York
# 5                  America/Los_Angeles
# 6                     America/New_York
# 7                     America/New_York
# 8                      America/Chicago
# 9                     America/New_York
# 10                 America/Los_Angeles
# 11                    America/New_York
# 12                    America/New_York
# 13                     America/Chicago
# 14                    America/New_York
# 15                   Asia/Kuala_Lumpur
# 16                     America/Chicago
# 17                    America/Edmonton
# 18                    America/New_York
# 19                     America/Chicago
# 20      America/Argentina/Buenos_Aires
# 21                       Asia/Calcutta
# 22                    America/New_York
# 23
# 24                     America/Chicago
# 25                       Europe/Moscow
# 26
# 27                     America/Chicago
# 28                    America/New_York
# 29                          Asia/Dubai
# ...                                ...
# 148461
# 148462
# 148463                   Europe/Zurich
# 148464                America/New_York
# 148465
# 148466                America/New_York
# 148467                America/New_York
# 148468                 America/Phoenix
# 148469             America/Los_Angeles
# 148470
# 148471
# 148472                      Asia/Tokyo
# 148473
# 148474                 America/Chicago
# 148475             America/Los_Angeles
# 148476                America/New_York
# 148477                America/New_York
# 148478                America/New_York
# 148479
# 148480                  America/Denver
# 148481                      Asia/Tokyo
# 148482             America/Los_Angeles
# 148483                America/New_York
# 148484                America/New_York
# 148485                America/New_York
# 148486                 America/Chicago
# 148487                 America/Chicago
# 148488                      Asia/Tokyo
# 148489
# 148490             America/Puerto_Rico
#
#                                                         u
# 0       http://pld.dpi.wi.gov/files/pld/images/LinkWI.png
# 1       http://studentaid.ed.gov/repay-loans/understan...
# 2       http://www.jpl.nasa.gov/spaceimages/details.ph...
# 3         http://activefiremaps.fs.fed.us/googleearth.php
# 4       http://www.samhsa.gov/underagedrinking?utm_sou...
# 5       http://www.cdc.gov/features/hearinglossdirectory/
# 6       http://apps.usfa.fema.gov/firefighter-fataliti...
# 7       http://apps.usfa.fema.gov/firefighter-fataliti...
# 8       http://pld.dpi.wi.gov/files/pld/images/LinkWI.png
# 9       http://apps.usfa.fema.gov/firefighter-fataliti...
# 10      http://blogs.usda.gov/2013/05/15/new-api-helps...
# 11      http://apps.usfa.fema.gov/firefighter-fataliti...
# 12      http://www.predictiveservices.nifc.gov/fuels_f...
# 13      http://pld.dpi.wi.gov/files/pld/images/LinkWI.png
# 14      http://www.portman.senate.gov/public/index.cfm...
# 15                                    http://www.nsa.gov/
# 16      http://www.af.mil/information/factsheets/facts...
# 17      http://www.nasa.gov/multimedia/imagegallery/im...
# 18      http://www.nsf.gov/news/news_summ.jsp?cntn_id=...
# 19      http://www.jpl.nasa.gov/news/news.php?release=...
# 20      http://www.jpl.nasa.gov/news/news.php?release=...
# 21      http://newscenter.lbl.gov/news-releases/2013/0...
# 22      http://www.michigan.gov/snyder/0,4668,7-277-57...
# 23                                    http://www.nsa.gov/
# 24      http://pld.dpi.wi.gov/files/pld/images/LinkWI.png
# 25           http://www.reid.senate.gov/contact/index.cfm
# 26      http://www.nasa.gov/mission_pages/asteroids/ne...
# 27      http://www.nasa.gov/topics/earth/features/glac...
# 28      http://www.choosemyplate.gov/food-groups/grain...
# 29      http://www.fda.gov/downloads/Drugs/DrugSafety/...
# ...                                                   ...
# 148461            http://apod.nasa.gov/apod/ap130517.html
# 148462  http://www.nasa.gov/mission_pages/station/expe...
# 148463  http://gsaauctions.gov/gsaauctions/aucdsclnk?s...
# 148464  http://gsaauctions.gov/gsaauctions/aucdsclnk?s...
# 148465                                http://www.nsa.gov/
# 148466  http://science.nasa.gov/science-news/science-a...
# 148467                                http://www.nsa.gov/
# 148468  http://cms3.tucsonaz.gov/files/police/media-re...
# 148469  http://www.irs.gov/uac/Newsroom/Tax-Relief-for...
# 148470  http://www.jpl.nasa.gov/news/news.php?release=...
# 148471  http://www.jpl.nasa.gov/news/news.php?release=...
# 148472  http://www.doe.gov/articles/energy-department-...
# 148473                                http://www.nsa.gov/
# 148474  http://pld.dpi.wi.gov/files/pld/images/LinkWI.png
# 148475  http://fwp.mt.gov/hunting/hunterAccess/openFie...
# 148476  http://science.nasa.gov/media/medialibrary/201...
# 148477  http://gsaauctions.gov/gsaauctions/aucdsclnk?s...
# 148478  http://inws.wrh.noaa.gov/weather/alertinfo/103...
# 148479  http://pld.dpi.wi.gov/files/pld/images/LinkWI.png
# 148480  http://doggett.house.gov/index.php/news/571-do...
# 148481  http://www.nasa.gov/mission_pages/mer/news/mer...
# 148482  http://fastlane.dot.gov/2013/05/new-locomotive...
# 148483  http://studentaid.ed.gov/repay-loans/understan...
# 148484  http://doggett.house.gov/index.php/news/571-do...
# 148485  http://doggett.house.gov/index.php/news/571-do...
# 148486  http://inws.wrh.noaa.gov/weather/alertinfo/103...
# 148487  http://pld.dpi.wi.gov/files/pld/images/LinkWI.png
# 148488  http://www.doe.gov/articles/energy-department-...
# 148489  http://www.jpl.nasa.gov/news/news.php?release=...
# 148490  http://science.nasa.gov/media/medialibrary/201...
#
# [148491 rows x 17 columns]

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148491 entries, 0 to 148490
# Data columns (total 17 columns):
# a     148491 non-null object
# al    118275 non-null object
# c     127847 non-null object
# cy    127847 non-null object
# g     148491 non-null object
# gr    127847 non-null object
# h     148491 non-null object
# hc    148491 non-null int64
# hh    148491 non-null object
# kw    21796 non-null object
# l     148491 non-null object
# ll    127675 non-null object
# nk    148491 non-null int64
# r     148491 non-null object
# t     148491 non-null int64
# tz    148491 non-null object
# u     148491 non-null object
# dtypes: int64(3), object(14)
# memory usage: 19.3+ MB

# %%
frame['tz'].value_counts()
# Out:
# America/Chicago                46235
# America/New_York               32832
#                                20850
# America/Los_Angeles            13898
# Europe/London                   4551
# America/Denver                  3235
# America/Rainy_River             1565
# Asia/Tokyo                      1514
# America/Phoenix                 1440
# Europe/Berlin                   1340
# America/Indianapolis            1330
# Asia/Calcutta                   1061
# Europe/Madrid                    892
# Europe/Amsterdam                 751
# Europe/Paris                     717
# Europe/Moscow                    716
# Europe/Rome                      698
# America/Sao_Paulo                557
# America/Montreal                 459
# Europe/Stockholm                 458
# Australia/NSW                    454
# America/Mexico_City              453
# America/Vancouver                452
# Australia/Victoria               431
# Asia/Hong_Kong                   374
# America/Edmonton                 363
# Asia/Manila                      339
# Africa/Johannesburg              323
# America/Puerto_Rico              317
# Europe/Brussels                  303
#                                ...
# America/Porto_Velho                2
# Asia/Makassar                      2
# America/St_Thomas                  2
# America/Dominica                   2
# America/Cayenne                    2
# Africa/Abidjan                     2
# Africa/Blantyre                    1
# Indian/Reunion                     1
# America/St_Kitts                   1
# Pacific/Marquesas                  1
# Asia/Aqtobe                        1
# America/Argentina/Catamarca        1
# America/Araguaina                  1
# Africa/Maseru                      1
# America/Argentina/Jujuy            1
# Africa/Dakar                       1
# Asia/Rangoon                       1
# America/Maceio                     1
# Europe/Vaduz                       1
# Asia/Thimphu                       1
# Europe/Kaliningrad                 1
# Europe/Mariehamn                   1
# Pacific/Fiji                       1
# Pacific/Noumea                     1
# America/Belize                     1
# Pacific/Port_Moresby               1
# Atlantic/Madeira                   1
# Asia/Bishkek                       1
# Asia/Vientiane                     1
# Asia/Gaza                          1
# Name: tz, Length: 239, dtype: int64
